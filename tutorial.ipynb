# %%
# Compute DPA for iron after 1 year in a reactor
ONE_YEAR = 3.15e7  # seconds

dpa = compute_dpa(
    flux=1e14,
    cross_section=iron['cross_section'],
    damage_energy=1000.0,
    displacement_energy=iron['displacement_energy'],
    time=ONE_YEAR,
)
print(f'DPA after 1 year: {dpa:.4e}')

# %%
# Get properties of iron
iron = get_material('iron')
print(iron)

# %%
from nrtdamage.physics import nrt_displacements, compute_dpa
from nrtdamage.materials import get_material, list_materials

# List all available materials
print('Available materials:', list_materials())

# %% [markdown]
# # NRTDamage Tutorial
#
# This notebook demonstrates how to use the 'NRTDamage' library to estimate
# radiation damage in nuclear materials using the NRT model.
#
# ## What is radiation damage?
#
# When neutrons strike atoms in a material, they can displace those atoms
# from their lattice positions. The **NRT model** estimates the number of
# such displacements, quantified as **DPA (displacements per atom)**.
